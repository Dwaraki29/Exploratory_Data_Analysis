# %% [markdown]
# Objective of Exploratory Data Analysis
# -->To bring out the quality of the data and make it ready for Machine Learning Modelling

# %%
#Import libraries 
import numpy as np #Faster Data Proceesing
import pandas as pd #EDA Purpose

# %%
# !pip install numpy pandas
# Out:
# Requirement already satisfied: numpy in c:\users\admin\yolov8_env\lib\site-packages (2.4.6)
# Collecting pandas
#   Using cached pandas-3.0.5-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\yolov8_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\admin\yolov8_env\lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\yolov8_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.5-cp311-cp311-win_amd64.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.0 MB 1.3 MB/s eta 0:00:08
#     --------------------------------------- 0.2/10.0 MB 1.7 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/10.0 MB 1.9 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/10.0 MB 2.1 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/10.0 MB 3.0 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.0/10.0 MB 3.3 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.3/10.0 MB 3.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.4/10.0 MB 3.7 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/10.0 MB 3.6 MB/s eta 0:00:03
#    ------- -------------------------------- 2.0/10.0 MB 3.9 MB/s eta 0:00:03
#    --------- ------------------------------ 2.4/10.0 MB 4.3 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/10.0 MB 4.3 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/10.0 MB 4.3 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/10.0 MB 4.3 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/10.0 MB 4.3 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/10.0 MB 4.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/10.0 MB 3.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/10.0 MB 3.7 MB/s eta 0:00:02
#    ------------ --------------------------- 3.1/10.0 MB 3.4 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/10.0 MB 4.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.0/10.0 MB 4.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/10.0 MB 4.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.3/10.0 MB 3.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.3/10.0 MB 3.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.3/10.0 MB 3.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.5/10.0 MB 3.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.5/10.0 MB 3.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.5/10.0 MB 3.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.5/10.0 MB 3.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.5/10.0 MB 3.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.5/10.0 MB 3.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.5/10.0 MB 3.7 MB/s eta 0:00:02
#    ------------------ --------------------- 4.6/10.0 MB 3.0 MB/s eta 0:00:02
#    ------------------ --------------------- 4.6/10.0 MB 2.9 MB/s eta 0:00:02
#    ------------------- -------------------- 4.9/10.0 MB 2.9 MB/s eta 0:00:02
#    ------------------- -------------------- 4.9/10.0 MB 3.0 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/10.0 MB 2.8 MB/s eta 0:00:02
#    -------------------- ------------------- 5.1/10.0 MB 2.8 MB/s eta 0:00:02
#    --------------------- ------------------ 5.3/10.0 MB 2.9 MB/s eta 0:00:02
#    --------------------- ------------------ 5.4/10.0 MB 2.8 MB/s eta 0:00:02
#    --------------------- ------------------ 5.4/10.0 MB 2.8 MB/s eta 0:00:02
#    --------------------- ------------------ 5.4/10.0 MB 2.8 MB/s eta 0:00:02
#    --------------------- ------------------ 5.4/10.0 MB 2.8 MB/s eta 0:00:02
#    --------------------- ------------------ 5.4/10.0 MB 2.8 MB/s eta 0:00:02
#    --------------------- ------------------ 5.4/10.0 MB 2.8 MB/s eta 0:00:02
#    --------------------- ------------------ 5.4/10.0 MB 2.8 MB/s eta 0:00:02
#    --------------------- ------------------ 5.4/10.0 MB 2.8 MB/s eta 0:00:02
#    --------------------- ------------------ 5.4/10.0 MB 2.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.5/10.0 MB 2.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.6/10.0 MB 2.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.6/10.0 MB 2.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.6/10.0 MB 2.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.6/10.0 MB 2.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.6/10.0 MB 2.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/10.0 MB 2.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/10.0 MB 2.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/10.0 MB 2.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.9/10.0 MB 2.2 MB/s eta 0:00:02
#    -------------------------- ------------- 6.6/10.0 MB 2.4 MB/s eta 0:00:02
#    -------------------------- ------------- 6.6/10.0 MB 2.4 MB/s eta 0:00:02
#    --------------------------- ------------ 6.8/10.0 MB 2.3 MB/s eta 0:00:02
#    --------------------------- ------------ 7.0/10.0 MB 2.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.0/10.0 MB 2.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.1/10.0 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.2/10.0 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.4/10.0 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.4/10.0 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.4/10.0 MB 2.4 MB/s eta 0:00:02
#    ------------------------------- -------- 8.0/10.0 MB 2.4 MB/s eta 0:00:01
#    -------------------------------- ------- 8.1/10.0 MB 2.4 MB/s eta 0:00:01
#    -------------------------------- ------- 8.1/10.0 MB 2.4 MB/s eta 0:00:01
#    -------------------------------- ------- 8.2/10.0 MB 2.4 MB/s eta 0:00:01
#    --------------------------------- ------ 8.3/10.0 MB 2.4 MB/s eta 0:00:01
#    --------------------------------- ------ 8.5/10.0 MB 2.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.8/10.0 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 9.1/10.0 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 9.4/10.0 MB 2.6 MB/s eta 0:00:01
#    -------------------------------------- - 9.6/10.0 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------  9.9/10.0 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.0 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.0/10.0 MB 2.6 MB/s eta 0:00:00
# Installing collected packages: pandas
# Successfully installed pandas-3.0.5
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Loading the data
data = pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#Understandin the data -->info(),describe(),columns(),unique(),value_count()
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
#reading columns
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
#we will seperate the columns
data.dtypes;
data.select_dtypes(include='object')  #object columns
data.select_dtypes(include = ['int','float'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4400\2679830438.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.select_dtypes(include='object')  #object columns
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
#Total number of passengers in the ship
print('Total number of passengers in the ship are',len(data))
# Out:
# Total number of passengers in the ship are 891

# %%
#Staticstical Distribution -->describe()
data.describe() #default -->numerical columns only
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include = 'object')
#top return most accuring value
#freq returns the count of most occuriing value
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4400\2468998782.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.describe(include = 'object')
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
#we try to understand the unique value in the columns
data['Ticket'].unique()
# Out:
# <StringArray>
# [       'A/5 21171',         'PC 17599', 'STON/O2. 3101282',
#            '113803',           '373450',           '330877',
#             '17463',           '349909',           '347742',
#            '237736',
#  ...
#            '349212',           '349217',           '349257',
#              '7552', 'C.A./SOTON 34068',  'SOTON/OQ 392076',
#            '211536',           '112053',           '111369',
#            '370376']
# Length: 681, dtype: str

# %%
data['Embarked'].unique() #Embarked  in place of travel
# Out:
# <StringArray>
# ['S', 'C', 'Q', nan]
# Length: 4, dtype: str

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
data['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
data['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
data['Pclass'].value_counts()
data['Pclass'].value_counts(ascending=True)
# Out:
# Pclass
# 2    184
# 1    216
# 3    491
# Name: count, dtype: int64

# %%
data['Age'].value_counts().head(30)
# Out:
# Age
# 24.0    30
# 22.0    27
# 18.0    26
# 28.0    25
# 19.0    25
# 30.0    25
# 21.0    24
# 25.0    23
# 36.0    22
# 29.0    20
# 26.0    18
# 35.0    18
# 27.0    18
# 32.0    18
# 31.0    17
# 16.0    17
# 20.0    15
# 34.0    15
# 33.0    15
# 23.0    15
# 39.0    14
# 40.0    13
# 42.0    13
# 17.0    13
# 45.0    12
# 38.0    11
# 2.0     10
# 4.0     10
# 50.0    10
# 47.0     9
# Name: count, dtype: int64

# %%
#to get any random sample in the dataset
data.sample(15)
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 668          669         0       3                        Cook, Mr. Jacob
# 16            17         0       3                   Rice, Master. Eugene
# 568          569         0       3                    Doharr, Mr. Tannous
# 696          697         0       3                       Kelly, Mr. James
# 357          358         0       2              Funk, Miss. Annie Clemmer
# 386          387         0       3        Goodwin, Master. Sidney Leonard
# 50            51         0       3             Panula, Master. Juha Niilo
# 485          486         0       3                 Lefebre, Miss. Jeannie
# 420          421         0       3                 Gheorgheff, Mr. Stanio
# 213          214         0       2            Givard, Mr. Hans Kristensen
# 362          363         0       3        Barbara, Mrs. (Catherine David)
# 466          467         0       2                  Campbell, Mr. William
# 137          138         0       1            Futrelle, Mr. Jacques Heath
# 375          376         1       1  Meyer, Mrs. Edgar Joseph (Leila Saks)
# 695          696         0       2             Chapman, Mr. Charles Henry
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 668    male  43.0      0      0  A/5 3536   8.0500   NaN        S
# 16     male   2.0      4      1    382652  29.1250   NaN        Q
# 568    male   NaN      0      0      2686   7.2292   NaN        C
# 696    male  44.0      0      0    363592   8.0500   NaN        S
# 357  female  38.0      0      0    237671  13.0000   NaN        S
# 386    male   1.0      5      2   CA 2144  46.9000   NaN        S
# 50     male   7.0      4      1   3101295  39.6875   NaN        S
# 485  female   NaN      3      1      4133  25.4667   NaN        S
# 420    male   NaN      0      0    349254   7.8958   NaN        C
# 213    male  30.0      0      0    250646  13.0000   NaN        S
# 362  female  45.0      0      1      2691  14.4542   NaN        C
# 466    male   NaN      0      0    239853   0.0000   NaN        S
# 137    male  37.0      1      0    113803  53.1000  C123        S
# 375  female   NaN      1      0  PC 17604  82.1708   NaN        C
# 695    male  52.0      0      0    248731  13.5000   NaN        S

# %%
data['Age'].value_counts().tail(30)
# Out:
# Age
# 0.83     2
# 59.00    2
# 71.00    2
# 32.50    2
# 40.50    2
# 45.50    2
# 63.00    2
# 10.00    2
# 64.00    2
# 13.00    2
# 0.75     2
# 57.00    2
# 70.00    2
# 30.50    2
# 66.00    1
# 14.50    1
# 70.50    1
# 12.00    1
# 36.50    1
# 55.50    1
# 20.50    1
# 23.50    1
# 0.92     1
# 53.00    1
# 80.00    1
# 24.50    1
# 0.67     1
# 0.42     1
# 34.50    1
# 74.00    1
# Name: count, dtype: int64

# %%
#DataVisualization -->matplotlib,seaborn,platly
import matplotlib.pyplot as plt #!pip install matplotlib

# %%
plt.hist(data['Age'],bins=15,color='yellow')
plt.title('Age Distribution')
plt.show()
